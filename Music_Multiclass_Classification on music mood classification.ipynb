# %%
# import the libraries

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# load the dataset
df=pd.read_csv(r"C:\Users\Administrator\Downloads\archive\data_moods.csv")
df.tail()
# Out:
#                                 name                            album  \
# 681                      windcatcher                      windcatcher
# 682  yellow is the color of her eyes  yellow is the color of her eyes
# 683               you broke me first               you broke me first
# 684              you were good to me                            brent
# 685                             æfre                             æfre
#
#             artist                      id release_date  popularity  length  \
# 681      Leo Nocta  59VApBbrS2IADQk4ml5mdo   2020-06-19          36  123066
# 682   Soccer Mommy  4D3nttJPU6L0M2epr7sId6   2019-11-19           5  435080
# 683     Tate McRae  45bE4HXI0AwGZXfZtMp8JR   2020-04-17          87  169265
# 684  Jeremy Zucker  4CxFN5zON70B3VOPBYbd6P   2019-05-03          76  219146
# 685          praam  2irbT1BSYaIEF44PlyKaoM   2020-07-17          41  186331
#
#      danceability  acousticness  energy  instrumentalness  liveness  valence  \
# ...

# %%
# finding all the coloums names of data
df.columns
# Out:
# Index(['name', 'album', 'artist', 'id', 'release_date', 'popularity', 'length',
#        'danceability', 'acousticness', 'energy', 'instrumentalness',
#        'liveness', 'valence', 'loudness', 'speechiness', 'tempo', 'key',
#        'time_signature', 'mood'],
#       dtype='object')

# %%
# defining our features and labels
# input features

X=df[['acousticness','danceability','energy','liveness','valence','tempo','speechiness','loudness','instrumentalness','popularity','key']]
 #Label
y=df['mood']

# %%
# locating the first five rows of the input data
X.head()
# Out:
#    acousticness  danceability  energy  liveness  valence    tempo  \
# 0       0.13700         0.866   0.730    0.0843    0.625  118.523
# 1       0.01890         0.381   0.832    0.1530    0.166  120.255
# 2       0.91300         0.346   0.139    0.0934    0.116  136.168
# 3       0.08900         0.466   0.438    0.1130    0.587  193.100
# 4       0.00171         0.419   0.932    0.1370    0.445  169.881
#
#    speechiness  loudness  instrumentalness  popularity  key
# 0       0.0767    -8.201          0.000000          68    5
# 1       0.0492    -5.069          0.196000          43    8
# 2       0.0321   -15.326          0.000077          60    0
# 3       0.0608   -12.858          0.000006           2    4
# 4       0.1060    -3.604          0.000000          60    1

# %%
# Label/Output Data
y.head()
# Out:
# 0        Happy
# 1          Sad
# 2          Sad
# 3        Happy
# 4    Energetic
# Name: mood, dtype: object

# %%
# shape of the datasets
df.shape
# Out:
# (686, 19)

# %%
# Spliting the datasets into training and test (80/20)
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=0)

# %%
# Shapes of train and test input and outputs
print("Train input data", X_train.shape)
print("Test input data", X_test.shape)
print("Train output data", y_train.shape)
print("Test output data", y_test.shape)
# Out:
# Train input data (548, 11)
# Test input data (138, 11)
# Train output data (548,)
# Test output data (138,)

# %%
# Creating the model using logistic regression
from sklearn.linear_model import LogisticRegression
# fit the model on training datasets
log_reg=LogisticRegression().fit(X_train,y_train)
log_reg
# Out:
# c:\Users\Administrator\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
# predicting the outcome on test datasets
y_pred=log_reg.predict(X_test)
y_pred
# Out:
# array(['Sad', 'Energetic', 'Calm', 'Energetic', 'Happy', 'Energetic',
#        'Energetic', 'Energetic', 'Sad', 'Calm', 'Calm', 'Sad', 'Sad',
#        'Energetic', 'Calm', 'Happy', 'Calm', 'Sad', 'Happy', 'Calm',
#        'Sad', 'Sad', 'Sad', 'Calm', 'Calm', 'Energetic', 'Sad', 'Sad',
#        'Energetic', 'Happy', 'Happy', 'Happy', 'Happy', 'Sad', 'Happy',
#        'Energetic', 'Calm', 'Sad', 'Calm', 'Sad', 'Energetic', 'Sad',
#        'Happy', 'Energetic', 'Energetic', 'Sad', 'Sad', 'Sad', 'Calm',
#        'Calm', 'Calm', 'Sad', 'Sad', 'Calm', 'Calm', 'Sad', 'Calm',
#        'Calm', 'Energetic', 'Energetic', 'Energetic', 'Happy', 'Calm',
#        'Energetic', 'Happy', 'Sad', 'Sad', 'Energetic', 'Sad',
#        'Energetic', 'Happy', 'Calm', 'Calm', 'Happy', 'Calm', 'Happy',
#        'Sad', 'Happy', 'Happy', 'Sad', 'Sad', 'Sad', 'Sad', 'Happy',
#        'Calm', 'Sad', 'Sad', 'Happy', 'Calm', 'Happy', 'Energetic', 'Sad',
# ...

# %%
# checking the accuracy test of data
score=log_reg.score(X_test,y_test)
print('The accuracy score is :', score)
print(score.mean())
# Out:
# The accuracy score is : 0.7028985507246377
# 0.7028985507246377

# %%
# Confusion matrix
from sklearn import metrics
cm=metrics.confusion_matrix(y_pred,y_test)
cm
# Out:
# array([[27,  0,  1,  3],
#        [ 0, 20,  9,  4],
#        [ 1,  6, 18,  4],
#        [ 8,  1,  4, 32]], dtype=int64)

# %%
plt.figure(figsize=(9,9))
sns.heatmap(cm,annot=True,fmt=".3f",linewidths=.5,square=True,cmap='Spectral');
plt.ylabel('Actual Output')
plt.xlabel('Predicted Output')
all_sample_title='Accuracy Score:{0}'.format(score)
plt.title(all_sample_title,size=15)
# Out:
# Text(0.5, 1.0, 'Accuracy Score:0.7028985507246377')

# %%
sns.barplot(df,x='mood',y='energy')
plt.show()

# %%
sns.barplot(df,x='mood',y='tempo')
plt.show()

# %%
df.columns
# Out:
# Index(['name', 'album', 'artist', 'id', 'release_date', 'popularity', 'length',
#        'danceability', 'acousticness', 'energy', 'instrumentalness',
#        'liveness', 'valence', 'loudness', 'speechiness', 'tempo', 'key',
#        'time_signature', 'mood'],
#       dtype='object')

# %%
sns.barplot(df,x='mood',y='acousticness')
plt.show()

# %%
sns.barplot(df,x='mood',y='valence')
plt.show()

# %%
sns.barplot(df,x='mood',y='instrumentalness')
plt.show()
